# %%
# ✅ 掛載 Google Drive
from google.colab import drive
drive.mount('/content/drive')

# ✅ 定位工作路徑
# %cd /content/drive/MyDrive/Colab\ Notebooks/CLIP_Anomaly_ZSAD/InCTRL-main

# ✅ Step 1: 轉換 VisA 資料結構
# !python datasets/preprocess/convert_visa.py \
  --dataset_root "/content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/VisA_20220922"
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/InCTRL-main
# Done
# /content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/datasets/AD_json/visa_normal.json /content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/datasets/AD_json/visa_outlier.json
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/InCTRL-main/datasets/preprocess/gen_train_json.py", line 26, in <module>
#     normal_train_files = os.listdir(os.path.join(image_dir, 'train', 'good'))
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/visa/visa/train/good'
# /content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/datasets/AD_json/visa_val_normal.json /content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/datasets/AD_json/visa_val_outlier.json
# Traceback (most recent call last):
# ...

# %%
# !ls "/content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/visa_anomaly_detection"
# !ls "/content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/visa_anomaly_detection/visa"
# !ls "/content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/visa_anomaly_detection/visa/candle"
# !ls "/content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/visa_anomaly_detection/visa/candle/ground_truth"
# !ls "/content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/visa_anomaly_detection/visa/candle/test"
# !ls "/content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/visa_anomaly_detection/visa/candle/train"
# !ls "/content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/visa_anomaly_detection/visa/candle/ground_truth/defect"
# !ls "/content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/visa_anomaly_detection/visa/candle/test/defect"
# !ls "/content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/visa_anomaly_detection/visa/candle/test/good"
# !ls "/content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/visa_anomaly_detection/visa/candle/train/good"
# Out:
# visa
# candle	  cashew      fryum	 macaroni2  pcb2  pcb4
# capsules  chewinggum  macaroni1  pcb1	    pcb3  pipe_fryum
# ground_truth  test  train
# defect
# defect	good
# good
# 000.png  012.png  024.png  036.png  048.png  060.png  072.png  084.png	096.png
# 001.png  013.png  025.png  037.png  049.png  061.png  073.png  085.png	097.png
# 002.png  014.png  026.png  038.png  050.png  062.png  074.png  086.png	098.png
# 003.png  015.png  027.png  039.png  051.png  063.png  075.png  087.png	099.png
# 004.png  016.png  028.png  040.png  052.png  064.png  076.png  088.png
# 005.png  017.png  029.png  041.png  053.png  065.png  077.png  089.png
# 006.png  018.png  030.png  042.png  054.png  066.png  078.png  090.png
# 007.png  019.png  031.png  043.png  055.png  067.png  079.png  091.png
# 008.png  020.png  032.png  044.png  056.png  068.png  080.png  092.png
# 009.png  021.png  033.png  045.png  057.png  069.png  081.png  093.png
# ...
