# %%
# ✅ 掛載 Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/datasets/AD_json"

# %%
# ✅ 定位工作路徑
# %cd /content/drive/MyDrive/Colab\ Notebooks/CLIP_Anomaly_ZSAD/InCTRL-main

# !python datasets/preprocess/gen_train_json.py \
  --dataset_dir "/content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/visa_anomaly_detection/visa" \
  --output_dir "/content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/datasets/AD_json" \
  --dataset_name "candle"
# Out:
# /content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/InCTRL-main
# /content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/datasets/AD_json/candle_normal.json /content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/datasets/AD_json/candle_outlier.json

# %%
# ✅ 批次產生 VisA 所有類別的 train JSON 檔案
visa_categories = [
    "candle", "capsules", "cashew", "chewinggum", "fryum",
    "macaroni1", "macaroni2", "pcb1", "pcb2", "pcb3",
    "pcb4", "pipe_fryum"
]

for category in visa_categories:
    print(f"\n🚀 Generating JSON for category: {category}")
    # !python datasets/preprocess/gen_train_json.py \
      --dataset_dir "/content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/visa_anomaly_detection/visa" \
      --output_dir "/content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/datasets/AD_json" \
      --dataset_name "{category}"
# Out:
# 🚀 Generating JSON for category: candle
# /content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/datasets/AD_json/candle_normal.json /content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/datasets/AD_json/candle_outlier.json
#
# 🚀 Generating JSON for category: capsules
# /content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/datasets/AD_json/capsules_normal.json /content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/datasets/AD_json/capsules_outlier.json
#
# 🚀 Generating JSON for category: cashew
# /content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/datasets/AD_json/cashew_normal.json /content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/datasets/AD_json/cashew_outlier.json
#
# 🚀 Generating JSON for category: chewinggum
# /content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/datasets/AD_json/chewinggum_normal.json /content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/datasets/AD_json/chewinggum_outlier.json
#
# 🚀 Generating JSON for category: fryum
# ...

# %%
# ✅ 定義 VisA 所有類別
visa_categories = [
    "candle", "capsules", "cashew", "chewinggum", "fryum",
    "macaroni1", "macaroni2", "pcb1", "pcb2", "pcb3",
    "pcb4", "pipe_fryum"
]

# ✅ 指定共用路徑
dataset_root = "/content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/visa_anomaly_detection/visa"
output_dir = "/content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/datasets/AD_json"

# ✅ 批次產生 train 與 val JSON
for category in visa_categories:
    print(f"\n🚀 產生 JSON for 類別：{category}")

    # ✅ 產生訓練用 JSON
    # !python datasets/preprocess/gen_train_json.py \
      --dataset_dir "{dataset_root}" \
      --output_dir "{output_dir}" \
      --dataset_name "{category}"

    # ✅ 產生驗證用 JSON
    # !python datasets/preprocess/gen_val_json.py \
      --dataset_dir "{dataset_root}" \
      --output_dir "{output_dir}" \
      --dataset_name "{category}"
# Out:
# 🚀 產生 JSON for 類別：candle
# /content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/datasets/AD_json/candle_normal.json /content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/datasets/AD_json/candle_outlier.json
# /content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/datasets/AD_json/candle_val_normal.json /content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/datasets/AD_json/candle_val_outlier.json
#
# 🚀 產生 JSON for 類別：capsules
# /content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/datasets/AD_json/capsules_normal.json /content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/datasets/AD_json/capsules_outlier.json
# /content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/datasets/AD_json/capsules_val_normal.json /content/drive/MyDrive/Colab Notebooks/CLIP_Anomaly_ZSAD/datasets/AD_json/capsules_val_outlier.json
#
# 🚀 產生 JSON for 類別：cashew
# ...
